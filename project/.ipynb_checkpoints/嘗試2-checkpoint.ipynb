# %% [markdown]
# # Loading Data

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("C:/Users/黃柏倫/Desktop/data/python project/大盤指數盤後數據.xlsx",header=0)

# %%
dg=pd.read_excel("C:/Users/黃柏倫/Desktop/data/python project/全球new.xlsx",header=0)

# %%
dg=dg[2:]

# %% [markdown]
# # API NN feat. 香港恆生資料

# %%
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
from sklearn.model_selection import train_test_split

# %%
from keras.models import Sequential
from keras.layers import Dense,LSTM, add

# %%
def nor(t):
    t-= t.min()
    t =t/t.max()
    return t

# %%
from keras.models import Model
from keras.layers import Input,concatenate,Dropout

# %%
df['年月日']=pd.to_datetime(df['年月日'])
dg['年月日']=pd.to_datetime(dg['年月日'])

# %%
d_txoc=df[['年月日','收盤價']]
d_txov=df[['年月日','成交值']]
d_ups=df[['年月日','漲跌平']]
d_hsi=dg[['年月日','香港恆生']]

# %%
DF=pd.merge(d_txoc,d_txov)
DF=pd.merge(DF,d_ups)
DF=pd.merge(DF,d_hsi)
DF.index=range(len(DF))
DF.head()
# Out:
#          年月日      收盤價       成交值  漲跌平     香港恆生
# 0 1997-01-04  6820.35  36466000  0.0  13222.8
# 1 1997-01-06  6844.75  35696000  1.0  13443.9
# 2 1997-01-07  6875.02  50760000  1.0  13420.2
# 3 1997-01-08  7019.43  79860000  2.0  13454.9
# 4 1997-01-09  7010.76  81908000  1.0  13198.1

# %%
len(DF)
# Out:
# 5637

# %%
dfc=np.array(DF['收盤價'])
dfv=np.array(DF['成交值'])
dfh=np.array(DF['香港恆生'])
dfups=np.array(DF['漲跌平'])
dfd=DF['年月日']

# %%
a=[]
b=[]
c=[]
y=[]
n=5
after=0
for i in range(len(DF.index)-n):
    a.append(dfc[after+i:after+i+n])
    b.append(dfv[after+i:after+i+n])
    c.append(dfh[after+i:after+i+n])
    y.append(DF.漲跌平[after+i+n])
a=np.array(a).reshape(len(a),n)
b=np.array(b).reshape(len(b),n)
c=np.array(c).reshape(len(b),n)
yy = np_utils.to_categorical(y, 3)

# %%
se=87
a_train,a_test,y_train,y_test=train_test_split(a,yy,test_size=0.3,random_state=se)
b_train,b_test,y_train,y_test=train_test_split(b,yy,test_size=0.3,random_state=se)
c_train,c_test,y_train,y_test=train_test_split(c,yy,test_size=0.3,random_state=se)

# %%
f_1 = Dense(300,input_dim=n, activation='sigmoid')
g_1 = Dense(300,input_dim=n, activation='sigmoid')
fg_1= Dense(150,input_dim=n, activation='relu')
h_1 = Dense(300,input_dim=n, activation='sigmoid')

z_1 = Dense(3, activation='softmax')

# %%
a0 = Input(shape=(n,))
b0 = Input(shape=(n,))
c0 = Input(shape=(n,))

a1 = f_1(a0)
b1 = g_1(b0)

u1 = concatenate([a1,b1])
ab = fg_1(u1)

c1 = h_1(c0)

u2 = concatenate([ab,c1])

q = z_1(u2)

# %%
model = Model([a0,b0,c0],q )
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_24 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# input_25 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 300)          1800        input_24[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 300)          1800        input_25[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 600)          0           dense_26[0][0]
#                                                                  dense_27[0][0]
# __________________________________________________________________________________________________
# input_26 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 150)          90150       concatenate_12[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 300)          1800        input_26[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 450)          0           dense_28[0][0]
#                                                                  dense_29[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 3)            1353        concatenate_13[0][0]
# ==================================================================================================
# Total params: 96,903
# Trainable params: 96,903
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer="adam",metrics=['acc'])#,validation)

# %%
model.fit([a_train,b_train,c_train], y_train,batch_size=100,epochs=10)
# Out:
# Epoch 1/10
# 3942/3942 [==============================] - 0s 56us/step - loss: 1.0838 - acc: 0.4201
# Epoch 2/10
# 3942/3942 [==============================] - 0s 55us/step - loss: 1.0835 - acc: 0.4059
# Epoch 3/10
# 3942/3942 [==============================] - 0s 50us/step - loss: 1.0748 - acc: 0.4224
# Epoch 4/10
# 3942/3942 [==============================] - 0s 58us/step - loss: 1.0761 - acc: 0.4178
# Epoch 5/10
# 3942/3942 [==============================] - 0s 55us/step - loss: 1.0856 - acc: 0.4097
# Epoch 6/10
# 3942/3942 [==============================] - 0s 66us/step - loss: 1.0770 - acc: 0.4115
# Epoch 7/10
# 3942/3942 [==============================] - 0s 48us/step - loss: 1.0775 - acc: 0.4193
# Epoch 8/10
# 3942/3942 [==============================] - 0s 63us/step - loss: 1.0846 - acc: 0.4148
# Epoch 9/10
# 3942/3942 [==============================] - 0s 51us/step - loss: 1.0778 - acc: 0.4181
# Epoch 10/10
# 3942/3942 [==============================] - 0s 55us/step - loss: 1.0762 - acc: 0.4211

# %%
model.evaluate([a_test,b_test,c_test], y_test)
# Out:
# 1690/1690 [==============================] - 0s 45us/step
# [1.096522833468646, 0.36804733733101]

# %%
model.predict([a_test,b_test,c_test])
# Out:
# array([[0.23383218, 0.41505378, 0.351114  ],
#        [0.20849621, 0.45266658, 0.33883718],
#        [0.21353261, 0.47770986, 0.30875757],
#        ...,
#        [0.25493115, 0.3594078 , 0.38566104],
#        [0.27324706, 0.38741246, 0.3393404 ],
#        [0.2462081 , 0.38403693, 0.3697549 ]], dtype=float32)

# %%
yp = model.predict([a,b,c])
ypp=np.argmax(yp,axis=1)

# %%
st=0
end=st+n+100

plt.figure(figsize=(12,2))
plt.scatter(dfd[n+st:end],dfc[n+st:end],c=y[st:end-n],s=10,cmap='cool')
plt.xticks(rotation=45)
plt.plot(dfd[n+st:end],dfc[n+st:end],c='black', linewidth=0.5)



plt.figure(figsize=(12,2))
plt.scatter(dfd[n+st:end],dfc[n+st:end],c=ypp[st:end-n],s=10,cmap='cool')
plt.xticks(rotation=45)
plt.plot(dfd[n+st:end],dfc[n+st:end],c='black', linewidth=0.5)

# %% [markdown]
# # NN feat. 外資

# %%
from keras.models import Model
from keras.layers import Input,concatenate,Dropout

# %%
df['年月日']=pd.to_datetime(df['年月日'])
dg['年月日']=pd.to_datetime(dg['年月日'])
df
# Out:
#              證券代碼        年月日       開盤價       最高價       最低價       收盤價    股價漲跌  \
# 0      Y9999 加權指數 1971-01-05       NaN       NaN       NaN    123.28     NaN
# 1      Y9999 加權指數 1971-01-06    123.28       NaN       NaN    122.93   -0.35
# 2      Y9999 加權指數 1971-01-07    122.93       NaN       NaN    122.51   -0.42
# 3      Y9999 加權指數 1971-01-08    122.51       NaN       NaN    121.94   -0.57
# 4      Y9999 加權指數 1971-01-09    121.94       NaN       NaN    121.13   -0.81
# 5      Y9999 加權指數 1971-01-11    121.13       NaN       NaN    122.04    0.91
# 6      Y9999 加權指數 1971-01-12    122.04       NaN       NaN    122.41    0.37
# 7      Y9999 加權指數 1971-01-13    122.41       NaN       NaN    122.38   -0.03
# 8      Y9999 加權指數 1971-01-14    122.38       NaN       NaN    121.88   -0.50
# 9      Y9999 加權指數 1971-01-15    121.88       NaN       NaN    123.03    1.15
# 10     Y9999 加權指數 1971-01-16    123.03       NaN       NaN    122.77   -0.26
# 11     Y9999 加權指數 1971-01-18    122.77       NaN       NaN    122.87    0.10
# 12     Y9999 加權指數 1971-01-19    122.87       NaN       NaN    124.22    1.35
# 13     Y9999 加權指數 1971-01-20    124.22       NaN       NaN    124.59    0.37
# 14     Y9999 加權指數 1971-01-21    124.59       NaN       NaN    124.43   -0.16
# 15     Y9999 加權指數 1971-01-22    124.43       NaN       NaN    125.77    1.34
# 16     Y9999 加權指數 1971-01-23    125.77       NaN       NaN    126.49    0.72
# 17     Y9999 加權指數 1971-01-25    126.49       NaN       NaN    126.89    0.40
# 18     Y9999 加權指數 1971-02-01    126.89       NaN       NaN    128.26    1.37
# 19     Y9999 加權指數 1971-02-02    128.26       NaN       NaN    127.90   -0.36
# 20     Y9999 加權指數 1971-02-03    127.90       NaN       NaN    128.02    0.12
# 21     Y9999 加權指數 1971-02-04    128.02       NaN       NaN    128.96    0.94
# 22     Y9999 加權指數 1971-02-05    128.96       NaN       NaN    129.75    0.79
# 23     Y9999 加權指數 1971-02-06    129.75       NaN       NaN    129.89    0.14
# 24     Y9999 加權指數 1971-02-08    129.89       NaN       NaN    130.04    0.15
# 25     Y9999 加權指數 1971-02-09    130.04       NaN       NaN    131.40    1.36
# 26     Y9999 加權指數 1971-02-10    131.40       NaN       NaN    130.81   -0.59
# 27     Y9999 加權指數 1971-02-11    130.81       NaN       NaN    132.25    1.44
# 28     Y9999 加權指數 1971-02-12    132.25       NaN       NaN    132.05   -0.20
# 29     Y9999 加權指數 1971-02-13    132.05       NaN       NaN    131.55   -0.50
# ...           ...        ...       ...       ...       ...       ...     ...
# 13124  Y9999 加權指數 2019-04-08  10759.96  10807.05  10759.96  10800.57   96.19
# 13125  Y9999 加權指數 2019-04-09  10805.39  10851.60  10793.77  10851.60   51.03
# 13126  Y9999 加權指數 2019-04-10  10839.93  10875.65  10815.61  10868.14   16.54
# 13127  Y9999 加權指數 2019-04-11  10869.24  10887.12  10797.76  10808.77  -59.37
# 13128  Y9999 加權指數 2019-04-12  10820.94  10836.44  10782.02  10805.30   -3.47
# 13144  0.008261  2.0  112796898  1.0      -780.86      -103.81  -115605.0
# 13145 -0.005773  0.0  110640781  0.0     -7131.91       983.48  -371158.0
# 13146 -0.017397  0.0  141861985  0.0    -18031.51      -611.51 -1062470.0
# 13147 -0.001927  1.0  125459729  0.0     -4959.33       280.96 -1305266.0
# 13148 -0.014440  0.0  114276157  0.0     -3626.48      1209.97 -1244458.0
# 13149 -0.003698  1.0  140099246  0.0    -10338.35      5427.54 -1085024.0
# 13150  0.003941  1.0  115662192  1.0    -12987.30       230.06   186100.0
# 13151 -0.008153  0.0  114790379  0.0    -12692.71      -567.22   -26752.0
# 13152 -0.008640  0.0  132151992  0.0     -8224.06      -565.14  -155299.0
# 13153  0.001377  1.0  108640936  1.0     -3221.47      2996.79  -612522.0
#
#         融券增減(張)
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# ...         ...
# 13124   -2911.0
# 13125  -25826.0
# 13126 -131934.0
# 13127  -11450.0
# 13128   25697.0
# 13129   62179.0
# 13130   42795.0
# 13131   42600.0
# 13132   44430.0
# 13133   38038.0
# 13134    5936.0
# 13135   31134.0
# 13136   11354.0
# 13137    4682.0
# 13138   -8492.0
# 13139   -3230.0
# 13140    7064.0
# 13141  -39871.0
# 13142  -31126.0
# 13143 -137191.0
# 13144  -24368.0
# 13145 -102912.0
# 13146  -22464.0
# 13147    6401.0
# 13148  -14281.0
# 13149  -13424.0
# 13150   10363.0
# 13151   15742.0
# 13152    6108.0
# 13153      90.0
#
# [13154 rows x 15 columns]

# %%
d_txoc=df[['年月日','收盤價']]
d_txov=df[['年月日','成交值']]
d_ups=df[['年月日','漲跌平']]
d_of=df[['年月日','外資買賣超市值(百萬)']]

# %%
DF=pd.merge(d_txoc,d_txov)
DF=pd.merge(DF,d_ups)
DF=pd.merge(DF,d_of)
DF=DF.dropna()
DF.index=range(len(DF))
DF.head()
# Out:
#          年月日      收盤價       成交值  漲跌平  外資買賣超市值(百萬)
# 0 1996-09-02  6342.17  35463000  1.0       561.85
# 1 1996-09-03  6257.97  37428000  0.0       132.37
# 2 1996-09-04  6228.78  40213000  1.0       897.03
# 3 1996-09-05  6304.96  39001000  2.0       759.03
# 4 1996-09-06  6290.23  31401000  1.0      -142.73

# %%
len(DF)
# Out:
# 5733

# %%
dfc=np.array(DF['收盤價'])
dfv=np.array(DF['成交值'])
dfo=np.array(DF['外資買賣超市值(百萬)'])
dfups=np.array(DF['漲跌平'])
dfd=DF['年月日']

# %%
a=[]
b=[]
c=[]
y=[]
n=5
after=0
for i in range(len(DF.index)-n):
    a.append(dfc[after+i:after+i+n])
    b.append(dfv[after+i:after+i+n])
    c.append(dfo[after+i:after+i+n])
    y.append(DF.漲跌平[after+i+n])
a=np.array(a).reshape(len(a),n)
b=np.array(b).reshape(len(b),n)
c=np.array(c).reshape(len(b),n)
yy = np_utils.to_categorical(y, 3)

# %%
se=87
a_train,a_test,y_train,y_test=train_test_split(a,yy,test_size=0.3,random_state=se)
b_train,b_test,y_train,y_test=train_test_split(b,yy,test_size=0.3,random_state=se)
c_train,c_test,y_train,y_test=train_test_split(c,yy,test_size=0.3,random_state=se)

# %%
f_1 = Dense(300,input_dim=n, activation='sigmoid')
g_1 = Dense(300,input_dim=n, activation='sigmoid')
h_1 = Dense(300,input_dim=n, activation='sigmoid')

z_1 = Dense(3, activation='softmax')

# %%
a0 = Input(shape=(n,))
b0 = Input(shape=(n,))
c0 = Input(shape=(n,))

a1 = f_1(a0)
b1 = g_1(b0)
c1 = h_1(c0)

u2 = concatenate([a1,c1])

q = z_1(u2)

# %%
model2 = Model([a0,b0,c0],q )
model2.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 300)          1800        input_15[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 300)          1800        input_17[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 600)          0           dense_15[1][0]
#                                                                  dense_17[1][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 3)            1803        concatenate_7[0][0]
# ==================================================================================================
# Total params: 5,403
# Trainable params: 5,403
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model2.compile(loss='categorical_crossentropy',optimizer="adam",metrics=['acc'])#,validation)

# %%
model2.fit([a_train,b_train,c_train], y_train,batch_size=100,epochs=20)
# Out:
# Epoch 1/20
# 4009/4009 [==============================] - 1s 139us/step - loss: 1.0651 - acc: 0.4283
# Epoch 2/20
# 4009/4009 [==============================] - 0s 38us/step - loss: 1.0621 - acc: 0.4388
# Epoch 3/20
# 4009/4009 [==============================] - 0s 35us/step - loss: 1.0600 - acc: 0.4350
# Epoch 4/20
# 4009/4009 [==============================] - 0s 38us/step - loss: 1.0664 - acc: 0.4298
# Epoch 5/20
# 4009/4009 [==============================] - 0s 34us/step - loss: 1.0695 - acc: 0.4273
# Epoch 6/20
# 4009/4009 [==============================] - 0s 31us/step - loss: 1.0603 - acc: 0.4370
# Epoch 7/20
# 4009/4009 [==============================] - 0s 30us/step - loss: 1.0699 - acc: 0.4171
# Epoch 8/20
# 4009/4009 [==============================] - 0s 32us/step - loss: 1.0561 - acc: 0.4330
# Epoch 9/20
# 4009/4009 [==============================] - 0s 29us/step - loss: 1.0504 - acc: 0.4487
# Epoch 10/20
# 4009/4009 [==============================] - 0s 29us/step - loss: 1.0548 - acc: 0.4425
# Epoch 11/20
# 4009/4009 [==============================] - 0s 34us/step - loss: 1.0492 - acc: 0.4507
# Epoch 12/20
# 4009/4009 [==============================] - 0s 32us/step - loss: 1.0473 - acc: 0.4530
# Epoch 13/20
# 4009/4009 [==============================] - 0s 28us/step - loss: 1.0463 - acc: 0.4535
# Epoch 14/20
# 4009/4009 [==============================] - 0s 25us/step - loss: 1.0468 - acc: 0.4440
# Epoch 15/20
# 4009/4009 [==============================] - 0s 32us/step - loss: 1.0560 - acc: 0.4410
# Epoch 16/20
# 4009/4009 [==============================] - 0s 22us/step - loss: 1.0516 - acc: 0.4542
# Epoch 17/20
# 4009/4009 [==============================] - 0s 28us/step - loss: 1.0491 - acc: 0.4535
# Epoch 18/20
# 4009/4009 [==============================] - 0s 32us/step - loss: 1.0509 - acc: 0.4502
# Epoch 19/20
# 4009/4009 [==============================] - 0s 26us/step - loss: 1.0544 - acc: 0.4418
# Epoch 20/20
# 4009/4009 [==============================] - 0s 26us/step - loss: 1.0552 - acc: 0.4480

# %%
model2.evaluate([a_test,b_test,c_test], y_test)
# Out:
# 1719/1719 [==============================] - 0s 28us/step
# [1.0980904294419525, 0.40314136134322953]

# %%
model2.predict([a_test,b_test,c_test])
# Out:
# array([[0.24617775, 0.43648213, 0.3173401 ],
#        [0.31774053, 0.29319355, 0.38906592],
#        [0.33969176, 0.4537317 , 0.20657648],
#        ...,
#        [0.24809694, 0.48052287, 0.27138022],
#        [0.25199264, 0.42221466, 0.3257927 ],
#        [0.24883595, 0.28556263, 0.4656015 ]], dtype=float32)

# %%
yp = model2.predict([a,b,c])
ypp=np.argmax(yp,axis=1)

# %%
st=0
end=st+n+100

plt.figure(figsize=(12,2))
plt.scatter(dfd[n+st:end],dfc[n+st:end],c=y[st:end-n],s=10,cmap='cool')
plt.xticks(rotation=45)
plt.plot(dfd[n+st:end],dfc[n+st:end],c='black', linewidth=0.5)



plt.figure(figsize=(12,2))
plt.scatter(dfd[n+st:end],dfc[n+st:end],c=ypp[st:end-n],s=10,cmap='cool')
plt.xticks(rotation=45)
plt.plot(dfd[n+st:end],dfc[n+st:end],c='black', linewidth=0.5)

# %%
ypp[:5]
# Out:
# array([2, 1, 1, 2, 1], dtype=int64)

# %% [markdown]
# # try everything (except global)

# %%
df['年月日']=pd.to_datetime(df['年月日'])
dg['年月日']=pd.to_datetime(dg['年月日'])
df
# Out:
#              證券代碼        年月日       開盤價       最高價       最低價       收盤價    股價漲跌  \
# 0      Y9999 加權指數 1971-01-05       NaN       NaN       NaN    123.28     NaN
# 1      Y9999 加權指數 1971-01-06    123.28       NaN       NaN    122.93   -0.35
# 2      Y9999 加權指數 1971-01-07    122.93       NaN       NaN    122.51   -0.42
# 3      Y9999 加權指數 1971-01-08    122.51       NaN       NaN    121.94   -0.57
# 4      Y9999 加權指數 1971-01-09    121.94       NaN       NaN    121.13   -0.81
# 5      Y9999 加權指數 1971-01-11    121.13       NaN       NaN    122.04    0.91
# 6      Y9999 加權指數 1971-01-12    122.04       NaN       NaN    122.41    0.37
# 7      Y9999 加權指數 1971-01-13    122.41       NaN       NaN    122.38   -0.03
# 8      Y9999 加權指數 1971-01-14    122.38       NaN       NaN    121.88   -0.50
# 9      Y9999 加權指數 1971-01-15    121.88       NaN       NaN    123.03    1.15
# 10     Y9999 加權指數 1971-01-16    123.03       NaN       NaN    122.77   -0.26
# 11     Y9999 加權指數 1971-01-18    122.77       NaN       NaN    122.87    0.10
# 12     Y9999 加權指數 1971-01-19    122.87       NaN       NaN    124.22    1.35
# 13     Y9999 加權指數 1971-01-20    124.22       NaN       NaN    124.59    0.37
# 14     Y9999 加權指數 1971-01-21    124.59       NaN       NaN    124.43   -0.16
# 15     Y9999 加權指數 1971-01-22    124.43       NaN       NaN    125.77    1.34
# 16     Y9999 加權指數 1971-01-23    125.77       NaN       NaN    126.49    0.72
# 17     Y9999 加權指數 1971-01-25    126.49       NaN       NaN    126.89    0.40
# 18     Y9999 加權指數 1971-02-01    126.89       NaN       NaN    128.26    1.37
# 19     Y9999 加權指數 1971-02-02    128.26       NaN       NaN    127.90   -0.36
# 20     Y9999 加權指數 1971-02-03    127.90       NaN       NaN    128.02    0.12
# 21     Y9999 加權指數 1971-02-04    128.02       NaN       NaN    128.96    0.94
# 22     Y9999 加權指數 1971-02-05    128.96       NaN       NaN    129.75    0.79
# 23     Y9999 加權指數 1971-02-06    129.75       NaN       NaN    129.89    0.14
# 24     Y9999 加權指數 1971-02-08    129.89       NaN       NaN    130.04    0.15
# 25     Y9999 加權指數 1971-02-09    130.04       NaN       NaN    131.40    1.36
# 26     Y9999 加權指數 1971-02-10    131.40       NaN       NaN    130.81   -0.59
# 27     Y9999 加權指數 1971-02-11    130.81       NaN       NaN    132.25    1.44
# 28     Y9999 加權指數 1971-02-12    132.25       NaN       NaN    132.05   -0.20
# 29     Y9999 加權指數 1971-02-13    132.05       NaN       NaN    131.55   -0.50
# ...           ...        ...       ...       ...       ...       ...     ...
# 13124  Y9999 加權指數 2019-04-08  10759.96  10807.05  10759.96  10800.57   96.19
# 13125  Y9999 加權指數 2019-04-09  10805.39  10851.60  10793.77  10851.60   51.03
# 13126  Y9999 加權指數 2019-04-10  10839.93  10875.65  10815.61  10868.14   16.54
# 13127  Y9999 加權指數 2019-04-11  10869.24  10887.12  10797.76  10808.77  -59.37
# 13128  Y9999 加權指數 2019-04-12  10820.94  10836.44  10782.02  10805.30   -3.47
# 13129  Y9999 加權指數 2019-04-15  10849.84  10897.21  10849.55  10875.60   70.30
# 13130  Y9999 加權指數 2019-04-16  10905.63  10927.85  10876.34  10927.85   52.25
# 13131  Y9999 加權指數 2019-04-17  10961.61  11016.92  10961.61  10997.26   69.41
# 13132  Y9999 加權指數 2019-04-18  11038.24  11077.99  10926.85  10962.02  -35.24
# 13133  Y9999 加權指數 2019-04-19  11017.69  11045.08  10950.43  10968.50    6.48
# 13134  Y9999 加權指數 2019-04-22  10994.52  11027.49  10974.82  10987.71   19.21
# 13135  Y9999 加權指數 2019-04-23  10994.28  11025.68  10949.30  11025.68   37.97
# 13136  Y9999 加權指數 2019-04-24  11054.02  11070.85  10995.83  11027.64    1.96
# 13137  Y9999 加權指數 2019-04-25  11017.73  11046.77  11006.68  11039.86   12.22
# 13138  Y9999 加權指數 2019-04-26  10986.53  10986.53  10906.44  10952.47  -87.39
# 13139  Y9999 加權指數 2019-04-29  10952.91  10992.55  10905.78  10939.06  -13.41
# 13140  Y9999 加權指數 2019-04-30  10945.94  10978.10  10910.78  10967.73   28.67
# 13141  Y9999 加權指數 2019-05-02  10992.76  11046.64  10988.70  11004.49   36.76
# 13142  Y9999 加權指數 2019-05-03  11037.99  11097.00  11018.86  11096.30   91.81
# 13143  Y9999 加權指數 2019-05-06  11005.36  11005.36  10870.40  10897.12 -199.18
# 13144  Y9999 加權指數 2019-05-07  10913.95  11004.76  10913.95  10987.14   90.02
# 13145  Y9999 加權指數 2019-05-08  10938.47  10946.82  10867.06  10923.71  -63.43
# 13146  Y9999 加權指數 2019-05-09  10910.47  10910.47  10732.97  10733.67 -190.04
# 13147  Y9999 加權指數 2019-05-10  10751.55  10834.69  10669.39  10712.99  -20.68
# 13148  Y9999 加權指數 2019-05-13  10684.04  10693.44  10549.06  10558.29 -154.70
# 13149  Y9999 加權指數 2019-05-14  10480.21  10544.97  10363.02  10519.25  -39.04
# 13150  Y9999 加權指數 2019-05-15  10535.24  10612.50  10535.24  10560.71   41.46
# 13151  Y9999 加權指數 2019-05-16  10556.58  10573.93  10474.61  10474.61  -86.10
# 13152  Y9999 加權指數 2019-05-17  10508.56  10564.97  10384.11  10384.11  -90.50
# 13153  Y9999 加權指數 2019-05-20  10405.36  10465.84  10385.18  10398.41   14.30
#
#         股價漲跌(%)  漲跌平        成交值   漲跌  外資買賣超市值(百萬)  自營買賣超市值(百萬)   融資增減(千元)  \
# 0           NaN  NaN      10000  NaN          NaN          NaN        NaN
# 1     -0.002839  1.0       4000  0.0          NaN          NaN        NaN
# 2     -0.003417  1.0      11000  0.0          NaN          NaN        NaN
# 3     -0.004653  1.0      14000  0.0          NaN          NaN        NaN
# 4     -0.006643  0.0      10000  0.0          NaN          NaN        NaN
# 5      0.007513  2.0       4000  1.0          NaN          NaN        NaN
# 6      0.003032  1.0       5000  1.0          NaN          NaN        NaN
# 7     -0.000245  1.0       4000  0.0          NaN          NaN        NaN
# 8     -0.004086  1.0      42000  0.0          NaN          NaN        NaN
# 9      0.009436  2.0      10000  1.0          NaN          NaN        NaN
# 10    -0.002113  1.0       9000  0.0          NaN          NaN        NaN
# 11     0.000815  1.0      10000  1.0          NaN          NaN        NaN
# 12     0.010987  2.0      14000  1.0          NaN          NaN        NaN
# 13     0.002979  1.0      18000  1.0          NaN          NaN        NaN
# 14    -0.001284  1.0       9000  0.0          NaN          NaN        NaN
# 15     0.010769  2.0      20000  1.0          NaN          NaN        NaN
# 16     0.005725  2.0      14000  1.0          NaN          NaN        NaN
# 17     0.003162  1.0      22000  1.0          NaN          NaN        NaN
# 18     0.010797  2.0      66000  1.0          NaN          NaN        NaN
# 19    -0.002807  1.0      36000  0.0          NaN          NaN        NaN
# 20     0.000938  1.0      23000  1.0          NaN          NaN        NaN
# 21     0.007343  2.0      29000  1.0          NaN          NaN        NaN
# 22     0.006126  2.0      27000  1.0          NaN          NaN        NaN
# 23     0.001079  1.0      19000  1.0          NaN          NaN        NaN
# 24     0.001155  1.0      16000  1.0          NaN          NaN        NaN
# 25     0.010458  2.0      32000  1.0          NaN          NaN        NaN
# 26    -0.004490  1.0      94000  0.0          NaN          NaN        NaN
# 13143 -137191.0
# 13144  -24368.0
# 13145 -102912.0
# 13146  -22464.0
# 13147    6401.0
# 13148  -14281.0
# 13149  -13424.0
# 13150   10363.0
# 13151   15742.0
# 13152    6108.0
# 13153      90.0
#
# [13154 rows x 15 columns]

# %%
d_txoc=df[['年月日','收盤價']]
d_txov=df[['年月日','成交值']]
d_ups=df[['年月日','漲跌平']]

d_of=df[['年月日','外資買賣超市值(百萬)']]
d_self=df[['年月日','自營買賣超市值(百萬)']]

d_high=df[['年月日','最高價']]
d_low=df[['年月日','最低價']]
d_borrow=df[['年月日','融資增減(千元)']]
d_tick=df[['年月日','融券增減(張)']]

# %%
def MER (a):
    s=a[0]
    for i in range(len(a)-1):
        s=pd.merge(s,a[i+1])
    return s

# %%
DF=MER([d_txoc,d_txov,d_ups,d_of,d_self,d_high,d_low,d_borrow,d_tick])
DF=DF.dropna()
DF.index=range(len(DF))
DF.head()
# Out:
#          年月日      收盤價       成交值  漲跌平  外資買賣超市值(百萬)  自營買賣超市值(百萬)      最高價  \
# 0 1996-09-18  6499.02  45207000  1.0       284.71          0.0  6508.13
# 1 1996-09-19  6535.59  51472000  2.0       403.21          0.0  6558.26
# 2 1996-09-20  6499.52  51295000  0.0       290.72          0.0  6546.36
# 3 1996-09-21  6490.09  37692000  1.0      -220.08          0.0  6528.81
# 4 1996-09-23  6453.98  40225000  0.0        24.20          0.0  6512.91
#
#        最低價   融資增減(千元)  融券增減(張)
# 0  6452.37   902185.0   6506.0
# 1  6535.59  1524201.0   6113.0
# 2  6492.30   114456.0   -906.0
# 3  6485.92   418937.0   6841.0
# 4  6447.46  -229998.0   8701.0

# %%
DF=pd.merge(d_txoc,d_txov)
DF=pd.merge(DF,d_ups)
DF=pd.merge(DF,d_of)
DF=DF.dropna()
DF.index=range(len(DF))
DF.head()
# Out:
#          年月日      收盤價       成交值  漲跌平  外資買賣超市值(百萬)
# 0 1996-09-02  6342.17  35463000  1.0       561.85
# 1 1996-09-03  6257.97  37428000  0.0       132.37
# 2 1996-09-04  6228.78  40213000  1.0       897.03
# 3 1996-09-05  6304.96  39001000  2.0       759.03
# 4 1996-09-06  6290.23  31401000  1.0      -142.73

# %%
len(DF)
# Out:
# 5566

# %%
dfc=np.array(DF['收盤價'])
dfv=np.array(DF['成交值'])
dfh=np.array(DF['最高價'])
dfl=np.array(DF['最低價'])

dfo=np.array(DF['外資買賣超市值(百萬)'])
dfs=np.array(DF['自營買賣超市值(百萬)'])

dfb=np.array(DF['融資增減(千元)'])
dft=np.array(DF['融券增減(張)'])
dfups=np.array(DF['漲跌平'])
dfd=DF['年月日']

# %%
def take (l,dl,n,after):
     for j in range(len(dl)):
        for i in range(len(DF.index)-n):
            l[j].append(dl[j][after+i:after+i+n])
        l[j]=np.array(l[j]).reshape(len(l[j]),n)

# %%
a1=[]
a2=[]
a3=[]
a4=[]
b1=[]
b2=[]
c1=[]
c2=[]
n=5
after=0
l=[a1,a2,a3,a4,b1,b2,c1,c2]
take(l,[dfc,dfv,dfh,dfl,dfo,dfs,dfb,dft],n,after)

# %%
y=[]
for i in range(len(DF.index)-n):
    y.append(DF.漲跌平[after+i+n])
yy = np_utils.to_categorical(y, 3)

# %%
x_train=[]
x_test=[]
F=[]
I0=[]
I1=[]
for i in range(len(l)):
    I0.append([])
    I1.append([])
    F.append([])
    x_train.append([])
    x_test.append([])
x_train
# Out:
# [[], [], [], [], [], [], [], []]

# %%
se=87
for i in range(len(l)):
    x_train[i],x_test[i],y_train,y_test=train_test_split(l[i],yy,test_size=0.3,random_state=se) 
    F[i] = Dense(300, activation='sigmoid')
    I0[i] = Input(shape=(n,))
    I1[i]= F[i](I0[i])

# %%
z= Dense(3, activation='softmax')

# %%
u2 = concatenate(I1)
q = z(u2)

# %%
model3 = Model(I0,q )
model3.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_28 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# input_29 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# input_30 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# input_31 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# input_32 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# input_33 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# input_34 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# input_35 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 300)          1800        input_28[0][0]
# __________________________________________________________________________________________________
# dense_48 (Dense)                (None, 300)          1800        input_29[0][0]
# __________________________________________________________________________________________________
# dense_49 (Dense)                (None, 300)          1800        input_30[0][0]
# __________________________________________________________________________________________________
# dense_50 (Dense)                (None, 300)          1800        input_31[0][0]
# __________________________________________________________________________________________________
# dense_51 (Dense)                (None, 300)          1800        input_32[0][0]
# __________________________________________________________________________________________________
# dense_52 (Dense)                (None, 300)          1800        input_33[0][0]
# __________________________________________________________________________________________________
# dense_53 (Dense)                (None, 300)          1800        input_34[0][0]
# __________________________________________________________________________________________________
# dense_54 (Dense)                (None, 300)          1800        input_35[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 2400)         0           dense_47[0][0]
#                                                                  dense_48[0][0]
#                                                                  dense_49[0][0]
#                                                                  dense_50[0][0]
#                                                                  dense_51[0][0]
#                                                                  dense_52[0][0]
#                                                                  dense_53[0][0]
#                                                                  dense_54[0][0]
# __________________________________________________________________________________________________
# dense_55 (Dense)                (None, 3)            7203        concatenate_9[0][0]
# ==================================================================================================
# Total params: 21,603
# Trainable params: 21,603
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model3.compile(loss='categorical_crossentropy',optimizer="adam",metrics=['acc'])#,validation)

# %%
model3.fit(x_train, y_train,batch_size=100,epochs=20)
# Out:
# Epoch 1/20
# 3892/3892 [==============================] - 2s 426us/step - loss: 1.1591 - acc: 0.3702
# Epoch 2/20
# 3892/3892 [==============================] - 0s 61us/step - loss: 1.1119 - acc: 0.4018
# Epoch 3/20
# 3892/3892 [==============================] - 0s 65us/step - loss: 1.0752 - acc: 0.4324
# Epoch 4/20
# 3892/3892 [==============================] - 0s 64us/step - loss: 1.0594 - acc: 0.4391
# Epoch 5/20
# 3892/3892 [==============================] - 0s 65us/step - loss: 1.0545 - acc: 0.4481
# Epoch 6/20
# 3892/3892 [==============================] - 0s 67us/step - loss: 1.0382 - acc: 0.4728
# Epoch 7/20
# 3892/3892 [==============================] - 0s 63us/step - loss: 1.0286 - acc: 0.4758
# Epoch 8/20
# 3892/3892 [==============================] - 0s 73us/step - loss: 1.0380 - acc: 0.4661
# Epoch 9/20
# 3892/3892 [==============================] - 0s 65us/step - loss: 1.0182 - acc: 0.4890
# Epoch 10/20
# 3892/3892 [==============================] - 0s 62us/step - loss: 1.0060 - acc: 0.4974
# Epoch 11/20
# 3892/3892 [==============================] - 0s 51us/step - loss: 1.0036 - acc: 0.4995
# Epoch 12/20
# 3892/3892 [==============================] - 0s 65us/step - loss: 0.9962 - acc: 0.4990
# Epoch 13/20
# 3892/3892 [==============================] - 0s 60us/step - loss: 0.9986 - acc: 0.5041
# Epoch 14/20
# 3892/3892 [==============================] - 0s 64us/step - loss: 0.9853 - acc: 0.5134
# Epoch 15/20
# 3892/3892 [==============================] - 0s 63us/step - loss: 0.9818 - acc: 0.5080
# Epoch 16/20
# 3892/3892 [==============================] - 0s 63us/step - loss: 0.9984 - acc: 0.4974
# Epoch 17/20
# 3892/3892 [==============================] - 0s 65us/step - loss: 0.9760 - acc: 0.5170
# Epoch 18/20
# 3892/3892 [==============================] - 0s 76us/step - loss: 0.9659 - acc: 0.5242: 0s - loss: 0.9522 - acc: 0.5
# Epoch 19/20
# 3892/3892 [==============================] - 0s 79us/step - loss: 0.9773 - acc: 0.5198
# Epoch 20/20
# 3892/3892 [==============================] - 0s 72us/step - loss: 0.9595 - acc: 0.5321

# %%
model3.evaluate(x_test, y_test)
# Out:
# 1669/1669 [==============================] - 0s 187us/step
# [1.1300005585651616, 0.4080287598077947]

# %%
model3.predict(x_test)
# Out:
# array([[0.25017592, 0.38889787, 0.36092615],
#        [0.15189393, 0.5109571 , 0.33714896],
#        [0.22305387, 0.362578  , 0.41436806],
#        ...,
#        [0.33613753, 0.46812034, 0.19574219],
#        [0.1940807 , 0.6172151 , 0.18870427],
#        [0.21485162, 0.50145054, 0.28369784]], dtype=float32)

# %%
yp = model3.predict(l)
ypp=np.argmax(yp,axis=1)

# %%
st=0
end=st+n+100

plt.figure(figsize=(12,2))
plt.scatter(dfd[n+st:end],dfc[n+st:end],c=y[st:end-n],s=10,cmap='cool')
plt.xticks(rotation=45)
plt.plot(dfd[n+st:end],dfc[n+st:end],c='black', linewidth=0.5)



plt.figure(figsize=(12,2))
plt.scatter(dfd[n+st:end],dfc[n+st:end],c=ypp[st:end-n],s=10,cmap='cool')
plt.xticks(rotation=45)
plt.plot(dfd[n+st:end],dfc[n+st:end],c='black', linewidth=0.5)
