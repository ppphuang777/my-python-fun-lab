# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ipywidgets import interact
import time

# %%
def f(t):
    return abs(t**2-100)

# %%
a=np.linspace(-20,20,10000)

# %%
b=np.abs(f(a))

# %%
plt.plot(a,b)

# %%
import numpy as np
from sympy.abc import x
from scipy.misc import derivative

# %%
def df(t):
    return derivative(f, t, dx=1e-6)

# %%
def run(s,lr):
    return s-lr*df(s)

# %% [markdown]
# # 顏色代號
#
# b: blue
#
# g: green
#
# r: red
#
# c: cyan
#
# m: magenta
#
# y: yellow
#
# k: black
#
# w: white

# %%
colorlist=list('bgrc')

# %%
s=[10*np.random.rand(1)-20,10*np.random.rand(1)-10,10*np.random.rand(1),10*np.random.rand(1)+10]
for i in range(4):
    lr=0.05
    plt.plot(a,b)
    for j in range(10):
        s[i]=run(s[i],lr)
        plt.scatter(s[i],f(s[i]),color=colorlist[i],s=50)
